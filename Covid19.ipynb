# %% [markdown]
# <a href="https://colab.research.google.com/github/CharlBrill89/Covid-19/blob/master/Covid19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Check out this kernel on Kaggle:
#
# https://www.kaggle.com/tarunkr/covid-19-case-study-analysis-viz-comparisons#COVID-19-Analysis,-Visualization,-Comparison-and-Predictions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker 
import folium
import branca
from datetime import datetime, timedelta,date
from scipy.interpolate import make_interp_spline, BSpline
import plotly.express as px
import json, requests

from keras.layers import Input, Dense, Activation, LeakyReLU
from keras import models
from keras.optimizers import RMSprop, Adam

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# Retrieving Dataset
df_confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
df_deaths = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
df_recovered = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
df_covid19 = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/web-data/data/cases_country.csv")
df_table = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/web-data/data/cases_time.csv",parse_dates=['Last_Update'])

# %%
# new dataset 
df_covid19 = df_covid19.drop(["People_Tested","People_Hospitalized","UID","ISO3","Mortality_Rate"],axis =1)

# %% [markdown]
# ## Data preprocessing

# %%
df_confirmed = df_confirmed.rename(columns={"Province/State":"State","Country/Region": "country"})
df_deaths = df_deaths.rename(columns={"Province/State":"State","Country/Region": "country"})
df_covid19 = df_covid19.rename(columns={"Country_Region": "country"})
df_covid19["Active"] = df_covid19["Confirmed"]-df_covid19["Recovered"]-df_covid19["Deaths"]
df_recovered = df_recovered.rename(columns={"Province/State":"state","Country/Region": "country"})

# %% [markdown]
# ### Convert country names

# %%
# Changing the conuntry names as required by pycountry_convert Lib
df_confirmed.loc[df_confirmed['country'] == "US", "country"] = "USA"
df_deaths.loc[df_deaths['country'] == "US", "country"] = "USA"
df_covid19.loc[df_covid19['country'] == "US", "country"] = "USA"
df_table.loc[df_table['Country_Region'] == "US", "Country_Region"] = "USA"
df_recovered.loc[df_recovered['country'] == "US", "country"] = "USA"

df_confirmed.loc[df_confirmed['country'] == 'Korea, South', "country"] = 'South Korea'
df_deaths.loc[df_deaths['country'] == 'Korea, South', "country"] = 'South Korea'
df_covid19.loc[df_covid19['country'] == "Korea, South", "country"] = "South Korea"
df_table.loc[df_table['Country_Region'] == "Korea, South", "Country_Region"] = "South Korea"
df_recovered.loc[df_recovered['country'] == 'Korea, South', "country"] = 'South Korea'

df_confirmed.loc[df_confirmed['country'] == 'Taiwan*', "country"] = 'Taiwan'
df_deaths.loc[df_deaths['country'] == 'Taiwan*', "country"] = 'Taiwan'
df_covid19.loc[df_covid19['country'] == "Taiwan*", "country"] = "Taiwan"
df_table.loc[df_table['Country_Region'] == "Taiwan*", "Country_Region"] = "Taiwan"
df_recovered.loc[df_recovered['country'] == 'Taiwan*', "country"] = 'Taiwan'

df_confirmed.loc[df_confirmed['country'] == 'Congo (Kinshasa)', "country"] = 'Democratic Republic of the Congo'
df_deaths.loc[df_deaths['country'] == 'Congo (Kinshasa)', "country"] = 'Democratic Republic of the Congo'
df_covid19.loc[df_covid19['country'] == "Congo (Kinshasa)", "country"] = "Democratic Republic of the Congo"
df_table.loc[df_table['Country_Region'] == "Congo (Kinshasa)", "Country_Region"] = "Democratic Republic of the Congo"
df_recovered.loc[df_recovered['country'] == 'Congo (Kinshasa)', "country"] = 'Democratic Republic of the Congo'

df_confirmed.loc[df_confirmed['country'] == "Cote d'Ivoire", "country"] = "Côte d'Ivoire"
df_deaths.loc[df_deaths['country'] == "Cote d'Ivoire", "country"] = "Côte d'Ivoire"
df_covid19.loc[df_covid19['country'] == "Cote d'Ivoire", "country"] = "Côte d'Ivoire"
df_table.loc[df_table['Country_Region'] == "Cote d'Ivoire", "Country_Region"] = "Côte d'Ivoire"
df_recovered.loc[df_recovered['country'] == "Cote d'Ivoire", "country"] = "Côte d'Ivoire"

df_confirmed.loc[df_confirmed['country'] == "Reunion", "country"] = "Réunion"
df_deaths.loc[df_deaths['country'] == "Reunion", "country"] = "Réunion"
df_covid19.loc[df_covid19['country'] == "Reunion", "country"] = "Réunion"
df_table.loc[df_table['Country_Region'] == "Reunion", "Country_Region"] = "Réunion"
df_recovered.loc[df_recovered['country'] == "Reunion", "country"] = "Réunion"

df_confirmed.loc[df_confirmed['country'] == 'Congo (Brazzaville)', "country"] = 'Republic of the Congo'
df_deaths.loc[df_deaths['country'] == 'Congo (Brazzaville)', "country"] = 'Republic of the Congo'
df_covid19.loc[df_covid19['country'] == "Congo (Brazzaville)", "country"] = "Republic of the Congo"
df_table.loc[df_table['Country_Region'] == "Congo (Brazzaville)", "Country_Region"] = "Republic of the Congo"
df_recovered.loc[df_recovered['country'] == 'Congo (Brazzaville)', "country"] = 'Republic of the Congo'

df_confirmed.loc[df_confirmed['country'] == 'Bahamas, The', "country"] = 'Bahamas'
df_deaths.loc[df_deaths['country'] == 'Bahamas, The', "country"] = 'Bahamas'
df_covid19.loc[df_covid19['country'] == "Bahamas, The", "country"] = "Bahamas"
df_table.loc[df_table['Country_Region'] == "Bahamas, The", "Country_Region"] = "Bahamas"
df_recovered.loc[df_recovered['country'] == 'Bahamas, The', "country"] = 'Bahamas'

df_confirmed.loc[df_confirmed['country'] == 'Gambia, The', "country"] = 'Gambia'
df_deaths.loc[df_deaths['country'] == 'Gambia, The', "country"] = 'Gambia'
df_covid19.loc[df_covid19['country'] == "Gambia, The", "country"] = "Gambia"
df_table.loc[df_table['Country_Region'] == "Gambia", "Country_Region"] = "Gambia"
df_recovered.loc[df_recovered['country'] == 'Gambia, The', "country"] = 'Gambia'

# getting all countries
countries = np.asarray(df_confirmed["country"])
countries1 = np.asarray(df_covid19["country"])
# Continent_code to Continent_names
continents = {
    'NA': 'North America',
    'SA': 'South America', 
    'AS': 'Asia',
    'OC': 'Australia',
    'AF': 'Africa',
    'EU' : 'Europe',
    'na' : 'Others'
}

# Defininng Function for getting continent code for country.
def country_to_continent_code(country):
    try:
        return pc.country_alpha2_to_continent_code(pc.country_name_to_country_alpha2(country))
    except :
        return 'na'

#Collecting Continent Information
#df_confirmed.insert(2,"continent", [continents[country_to_continent_code(country)] for country in countries[:]])
#df_deaths.insert(2,"continent",  [continents[country_to_continent_code(country)] for country in countries[:]])
#df_covid19.insert(1,"continent",  [continents[country_to_continent_code(country)] for country in countries1[:]])
#df_table.insert(1,"continent",  [continents[country_to_continent_code(country)] for country in df_table["Country_Region"].values])
#df_recovered.insert(2,"continent",  [continents[country_to_continent_code(country)] for country in countries[:]] )

# %% [markdown]
# ##Other stuff

# %%
df_confirmed = df_confirmed.replace(np.nan, '', regex=True)
df_deaths = df_deaths.replace(np.nan, '', regex=True)

# %%
#df_countries_cases = df_covid19.copy().drop(['Lat','Long_','continent','Last_Update'],axis =1)
df_countries_cases = df_covid19.copy().drop(['Lat','Long_','Last_Update'],axis =1)
df_countries_cases.index = df_countries_cases["country"]
df_countries_cases = df_countries_cases.drop(['country'],axis=1)

df_continents_cases = df_covid19.copy().drop(['Lat','Long_','country','Last_Update'],axis =1)
#df_continents_cases = df_continents_cases.groupby(["continent"]).sum()

df_countries_cases.fillna(0,inplace=True)
df_continents_cases.fillna(0,inplace=True)

# %%
df_t = pd.DataFrame(pd.to_numeric(df_countries_cases.sum()),dtype=np.float64).transpose()
df_t["Mortality Rate (per 100)"] = np.round(100*df_t["Deaths"]/df_t["Confirmed"],2)
df_t.style.background_gradient(cmap='Wistia',axis=1).format("{:,.0f}")
# Out:
# <style  type="text/css" >
#     #T_156ca8a8_91fa_11ea_aeaa_0242ac1c0002row0_col0 {
#             background-color:  #fc7f00;
#             color:  #000000;
#         }    #T_156ca8a8_91fa_11ea_aeaa_0242ac1c0002row0_col1 {
#             background-color:  #ebf960;
#             color:  #000000;
#         }    #T_156ca8a8_91fa_11ea_aeaa_0242ac1c0002row0_col2 {
#             background-color:  #ffd911;
#             color:  #000000;
#         }    #T_156ca8a8_91fa_11ea_aeaa_0242ac1c0002row0_col3 {
#             background-color:  #ffb200;
#             color:  #000000;
#         }    #T_156ca8a8_91fa_11ea_aeaa_0242ac1c0002row0_col4 {
#             background-color:  #e4ff78;
#             color:  #000000;
#         }    #T_156ca8a8_91fa_11ea_aeaa_0242ac1c0002row0_col5 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }</style><table id="T_156ca8a8_91fa_11ea_aeaa_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Confirmed</th>        <th class="col_heading level0 col1" >Deaths</th>        <th class="col_heading level0 col2" >Recovered</th>        <th class="col_heading level0 col3" >Active</th>        <th class="col_heading level0 col4" >Incident_Rate</th>        <th class="col_heading level0 col5" >Mortality Rate (per 100)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_156ca8a8_91fa_11ea_aeaa_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_156ca8a8_91fa_11ea_aeaa_0242ac1c0002row0_col0" class="data row0 col0" >3,961,594</td>
#                         <td id="T_156ca8a8_91fa_11ea_aeaa_0242ac1c0002row0_col1" class="data row0 col1" >275,397</td>
#                         <td id="T_156ca8a8_91fa_11ea_aeaa_0242ac1c0002row0_col2" class="data row0 col2" >1,334,463</td>
#                         <td id="T_156ca8a8_91fa_11ea_aeaa_0242ac1c0002row0_col3" class="data row0 col3" >2,351,734</td>
#                         <td id="T_156ca8a8_91fa_11ea_aeaa_0242ac1c0002row0_col4" class="data row0 col4" >17,281</td>
#                         <td id="T_156ca8a8_91fa_11ea_aeaa_0242ac1c0002row0_col5" class="data row0 col5" >7</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #Country wide cases

# %%
#df_countries_cases.sort_values('Confirmed', ascending= False).style.background_gradient(cmap='Wistia')
df_countries_cases["Mortality Rate (per 100)"] = np.round(100*df_countries_cases["Deaths"]/df_countries_cases["Confirmed"],2)
df_countries_cases.sort_values('Confirmed', ascending= False).head(20).style.background_gradient(cmap='Blues',subset=["Confirmed"])\
                        .background_gradient(cmap='Reds',subset=["Deaths"])\
                        .background_gradient(cmap='Greens',subset=["Recovered"])\
                        .background_gradient(cmap='Purples',subset=["Active"])\
                        .background_gradient(cmap='Pastel1_r',subset=["Incident_Rate"])\
                        .background_gradient(cmap='YlOrBr',subset=["Mortality Rate (per 100)"]).format("{:,.1f}")
# Out:
# <style  type="text/css" >
#     #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row0_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row0_col3 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row0_col4 {
#             background-color:  #b3cde3;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row0_col5 {
#             background-color:  #fecc61;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row1_col0 {
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row1_col1 {
#             background-color:  #fc9e80;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row1_col2 {
#             background-color:  #39a257;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row1_col3 {
#             background-color:  #f5f4f9;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row1_col4 {
#             background-color:  #fbb4ae;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row1_col5 {
#             background-color:  #d55607;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row2_col0 {
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row2_col1 {
#             background-color:  #fc8e6e;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row2_col2 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row2_col3 {
#             background-color:  #f3f1f7;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row2_col4 {
#             background-color:  #ccebc5;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row2_col5 {
#             background-color:  #a43904;
#             color:  #f1f1f1;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row3_col0 {
#             background-color:  #dae8f6;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row3_col1 {
#             background-color:  #fc8969;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row3_col2 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row3_col3 {
#             background-color:  #e6e5f1;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row3_col4 {
#             background-color:  #decbe4;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row3_col5 {
#             background-color:  #8e3104;
#             color:  #f1f1f1;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row4_col0 {
#             background-color:  #dceaf6;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row4_col1 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row4_col2 {
#             background-color:  #ddf2d8;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row4_col3 {
#             background-color:  #e9e8f2;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row4_col4 {
#             background-color:  #e5d8bd;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row4_col5 {
#             background-color:  #fffee0;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row5_col0 {
#             background-color:  #dfecf7;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row5_col1 {
#             background-color:  #fc9e80;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row5_col2 {
#             background-color:  #bee5b8;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row5_col3 {
#             background-color:  #f3f1f7;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row5_col4 {
#             background-color:  #decbe4;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row5_col5 {
#             background-color:  #8b3005;
#             color:  #f1f1f1;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row6_col0 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row6_col1 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row6_col2 {
#             background-color:  #2a924a;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row6_col3 {
#             background-color:  #faf9fc;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row6_col4 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row6_col5 {
#             background-color:  #fee595;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row7_col0 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row7_col1 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row7_col2 {
#             background-color:  #b8e3b2;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row7_col3 {
#             background-color:  #f4f3f8;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row7_col4 {
#             background-color:  #fddaec;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row7_col5 {
#             background-color:  #febe4a;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row8_col0 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row8_col1 {
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row8_col2 {
#             background-color:  #8bcf89;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row8_col3 {
#             background-color:  #f8f6fa;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row8_col4 {
#             background-color:  #e5d8bd;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row8_col5 {
#             background-color:  #fff6ba;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row9_col0 {
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row9_col1 {
#             background-color:  #fee7dc;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row9_col2 {
#             background-color:  #8ed08b;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row9_col3 {
#             background-color:  #fbfafc;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row9_col4 {
#             background-color:  #e5d8bd;
#             color:  #000000;
#         }    #T_e58b3932_91fa_11ea_aeaa_0242ac1c0002row9_col5 {
#             background-color:  #fec95b;
#             color:  #000000;
